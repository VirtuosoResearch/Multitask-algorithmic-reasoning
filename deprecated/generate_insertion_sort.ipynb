# %%
# %pwd
# %cd ..
# Out:
# /home/ldy/in-context-learning/algorithm-reasoning

# %%
from algorithms.utils import add_result_to_csv
from algorithms import insertion_sort, bubble_sort, selection_sort
import numpy as np
import os

'''
Natural language description
'''

# save results into .csv
file_dir = "./data/insertion_sort/"
if not os.path.exists(file_dir):
    os.makedirs(file_dir)
file_name = os.path.join(file_dir, "length_2_test.csv")

for _ in range(1000):
    arr = np.random.randint(0, 100, 2)
    instance = {
        "input": list(arr.copy()),
    }
    output_arr, intermediate_steps, intermediate_variables, comparisons, swaps = insertion_sort(arr)
    instance.update({
        "output": list(output_arr.copy()),
        "intermediate_steps": intermediate_steps,
        "intermediate_variables": intermediate_variables,
    })
    add_result_to_csv(instance, file_name)
    # print(instance["input"])
    # print(instance["intermediate_steps"])
    # print(instance["intermediate_variables"])

# %%
from algorithms.utils import add_result_to_csv
from algorithms import insertion_sort, bubble_sort, selection_sort
import numpy as np
import os


# save results into .csv
length = 5
data_size = 1000000
file_dir = "./data/insertion_sort/"
if not os.path.exists(file_dir):
    os.makedirs(file_dir)
file_name = os.path.join(file_dir, f"new_length_{length}.csv")

for _ in range(data_size):
    arr = np.random.randint(0, 100, length)
    instance = {
        "input": " ".join([str(i) for i in arr]),
    }
    output_arr, intermediate_steps, intermediate_variables, comparisons, swaps = insertion_sort(arr)
    instance.update({
        "output": " ".join([str(i) for i in output_arr]),
        # "intermediate_steps": intermediate_steps,
        # "intermediate_variables": intermediate_variables,
    })
    add_result_to_csv(instance, file_name)

# %%
# Out:
# [{'i': 0, 'j': 1, 'swap': True},
#  {'i': 1, 'j': 2, 'swap': False},
#  {'i': 2, 'j': 3, 'swap': True},
#  {'i': 1, 'j': 2, 'swap': False},
#  {'i': 3, 'j': 4, 'swap': True},
#  {'i': 2, 'j': 3, 'swap': False}]
